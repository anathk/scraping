# %%
# %pwd
# Out:
# '/home/zchao/github/scraping/apkcrawler/apkcrawler/spiders'

# %%
# %run apkpure.py
# Out:
# Start crawling process...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/zchao/anaconda3/envs/general/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/zchao/anaconda3/envs/general/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/zchao/anaconda3/envs/general/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/zchao/anaconda3/envs/general/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/zchao/anaconda3/envs/general/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/zchao/anaconda3/envs/general/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
# ...
